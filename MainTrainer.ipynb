# %%
import yfinance as yf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn import metrics
import warnings
import numpy as np
from joblib import dump
warnings.filterwarnings('ignore')
import os

# %%
stock_list=pd.read_csv('stocks.txt')
stock_list.head()
# Out:
#   Stocks
# 0    ABT
# 1   ABBV
# 2   ABMD
# 3    ACN
# 4   ATVI

# %%
def load_data(stock):
    ticker = yf.Ticker(ticker_symbol)
    data = ticker.history(period="max")
    data=data.reset_index()
    data['Date']=data['Date'].astype(str)
    data['Date']= data['Date'].str.split(expand=True)[0]
     # Split the Date column into year, month, and day
    splitted = data['Date'].astype(str).str.split('-', expand=True)
    
    # Add the splitted columns back to the DataFrame
    data['Year'] = splitted[0].astype(int)
    data['Month'] = splitted[1].astype(int)
    data['Day'] = splitted[2].astype(int)
    data=data.drop(['Date','Dividends','Stock Splits'],axis=1)

    data['is_quarter_end'] = np.where(data['Month']%3==0,1,0)

    data['open-close'] = data['Open'] - data['Close']
    data['high-low'] = data['High'] - data['Low']
    data['target'] = np.where(data['Close'].shift(-1) > data['Close'], 1, 0)
    
    print(data.columns.tolist())
    return data

# %%
data=load_data(stock_list['Stocks'][0])
data.head()
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
#        Open      High       Low     Close     Volume  Year  Month  Day  \
# 0  1.266667  1.666667  1.169333  1.592667  281494500  2010      6   29
# 1  1.719333  2.028000  1.553333  1.588667  257806500  2010      6   30
# 2  1.666667  1.728000  1.351333  1.464000  123282000  2010      7    1
# 3  1.533333  1.540000  1.247333  1.280000   77097000  2010      7    2
# 4  1.333333  1.333333  1.055333  1.074000  103003500  2010      7    6
#
#    is_quarter_end  open-close  high-low  target
# 0               1   -0.326000  0.497334       0
# 1               1    0.130666  0.474667       0
# 2               0    0.202667  0.376667       0
# 3               0    0.253333  0.292667       0
# 4               0    0.259333  0.278000       0

# %%
def train_model(stock_list):
    for stock in stock_list['Stocks']:
        data=load_data(stock)
        features=data[['open-close','high-low','is_quarter_end']]
        target=data['target']
        scaler=StandardScaler()
        scaler = scaler.fit_transform(features)
        X_train,X_test,Y_train,Y_test=train_test_split(features,target,test_size=0.1,random_state=2022)
        #print(X_train.shape,X_test.shape)
        models = [LogisticRegression(), SVC(
        kernel='poly', probability=True), XGBClassifier()]
        directory_name="./models/"+stock+"/" #directory for saving model
        if not os.path.exists(directory_name):
            os.mkdir(directory_name)
        LR="./models/"+stock+"/"+stock+"_LR.joblib"
        SV="./models/"+stock+"/"+stock+"_SVC.joblib"
        XGB="./models/"+stock+"/"+stock+"_XGB.joblib"
        modelsave=[LR,SV,XGB]
        for i in range(3):
            models[i].fit(X_train, Y_train)
            
            print(f'{stock} {models[i]} : ')
            print('Training Accuracy : ', metrics.roc_auc_score(Y_train, models[i].predict_proba(X_train)[:,1]))
            print('Validation Accuracy : ', metrics.roc_auc_score(Y_test, models[i].predict_proba(X_test)[:,1]))
            dump(models[i],modelsave[i])

# %%
train_model(stock_list)
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ABT LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ABT SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854719958660065
# Validation Accuracy :  0.4900290065264684
# ABT XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ABBV LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ABBV SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985423736238118
# Validation Accuracy :  0.4900290065264684
# ABBV XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ABMD LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ABMD SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985423736238117
# Validation Accuracy :  0.49001389896059944
# ABMD XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ACN LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ACN SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985423736238118
# Validation Accuracy :  0.4900290065264684
# ACN XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ATVI LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ATVI SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985431160796254
# Validation Accuracy :  0.4900290065264684
# ATVI XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ADBE LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ADBE SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985434873075323
# Validation Accuracy :  0.4900290065264684
# ADBE XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AMD LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AMD SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985423736238118
# Validation Accuracy :  0.4900290065264684
# AMD XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AAP LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AAP SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# AAP XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AES LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AES SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# AES XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AFL LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AFL SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985431160796254
# Validation Accuracy :  0.4900290065264684
# AFL XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# A LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# A SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854070309823095
# Validation Accuracy :  0.49001389896059944
# A XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# APD LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# APD SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# APD XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AKAM LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AKAM SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49853680520520927
# Validation Accuracy :  0.4900290065264684
# AKAM XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ALK LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ALK SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985375476610229
# Validation Accuracy :  0.4900290065264684
# ALK XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ALB LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ALB SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985447866052062
# Validation Accuracy :  0.4900290065264684
# ALB XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ARE LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ARE SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# ARE XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ALXN LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ALXN SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854385853543914
# Validation Accuracy :  0.49001389896059944
# ALXN XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ALGN LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ALGN SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985455290610199
# Validation Accuracy :  0.4900290065264684
# ALGN XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ALLE LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ALLE SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854571467497333
# Validation Accuracy :  0.4900290065264684
# ALLE XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ALL LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ALL SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854590028892665
# Validation Accuracy :  0.4900290065264684
# ALL XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AMZN LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AMZN SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985416311679981
# Validation Accuracy :  0.4900290065264684
# AMZN XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AMCR LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AMCR SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854571467497333
# Validation Accuracy :  0.4900290065264684
# AMCR XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AEE LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AEE SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854144555404467
# Validation Accuracy :  0.49001389896059944
# AEE XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AAL LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AAL SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# AAL XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AEP LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AEP SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985375476610229
# Validation Accuracy :  0.4900290065264684
# AEP XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AXP LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AXP SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985416311679981
# Validation Accuracy :  0.4900290065264684
# AXP XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AIG LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AIG SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985473852005541
# Validation Accuracy :  0.4900290065264684
# AIG XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AMT LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AMT SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985423736238118
# Validation Accuracy :  0.4900290065264684
# AMT XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AWK LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AWK SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854794204241426
# Validation Accuracy :  0.4900290065264684
# AWK XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AMP LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AMP SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985455290610199
# Validation Accuracy :  0.4900290065264684
# AMP XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ABC LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ABC SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985440441493926
# Validation Accuracy :  0.4900290065264684
# ABC XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AME LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AME SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# AME XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AMGN LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AMGN SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49855907887961937
# Validation Accuracy :  0.4900290065264684
# AMGN XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# APH LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# APH SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985431160796254
# Validation Accuracy :  0.4900290065264684
# APH XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ADI LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ADI SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985423736238118
# Validation Accuracy :  0.4900290065264684
# ADI XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ANSS LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ANSS SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985473852005541
# Validation Accuracy :  0.4900290065264684
# ANSS XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ANTM LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ANTM SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985481276563677
# Validation Accuracy :  0.4900290065264684
# ANTM XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AON LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AON SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985423736238117
# Validation Accuracy :  0.49001389896059944
# AON XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# AOS LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# AOS SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985375476610229
# Validation Accuracy :  0.4900290065264684
# AOS XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# APA LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# APA SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# APA XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
# ...
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# WLTW LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# WLTW SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985473852005541
# Validation Accuracy :  0.4900290065264684
# WLTW XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# WYNN LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# WYNN SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985455290610199
# Validation Accuracy :  0.4900290065264684
# WYNN XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# XRAY LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# XRAY SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# XRAY XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# XOM LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# XOM SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# XOM XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# XEL LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# XEL SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854070309823095
# Validation Accuracy :  0.49001389896059944
# XEL XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# XRX LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# XRX SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985395894145105
# Validation Accuracy :  0.4900290065264684
# XRX XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# XLNX LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# XLNX SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# XLNX XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# XYL LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# XYL SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985462715168335
# Validation Accuracy :  0.4900290065264684
# XYL XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# YUM LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# YUM SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# YUM XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ZBRA LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ZBRA SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49854590028892665
# Validation Accuracy :  0.4900290065264684
# ZBRA XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ZBH LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ZBH SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.49853940380055706
# Validation Accuracy :  0.49001389896059944
# ZBH XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ZION LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ZION SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.4985470139726472
# Validation Accuracy :  0.4900290065264684
# ZION XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Year', 'Month', 'Day', 'is_quarter_end', 'open-close', 'high-low', 'target']
# ZTS LogisticRegression() :
# Training Accuracy :  0.5231284266655976
# Validation Accuracy :  0.5055897993715253
# ZTS SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.5014542853250268
# Validation Accuracy :  0.5099709934735316
# ZTS XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.9022478963442588
# Validation Accuracy :  0.45277374909354606
